# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard__jjUmu  white-box-border jobCard"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)

company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_lists__fdnsc"]')   
for i in company_tags:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 60 60 60 60

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                 Title         Location  \
# 0
# 1   Premium\n4 days ago\nReq. for the Technology A...             Pune
# 2   Premium\n4 days ago\nWe need Process Lead\ninf...          Chennai
# 3   Premium\n4 days ago\nWe need Technical Operati...        Bangalore
# 4
# 5
# 6
# 7   Hot\n2 days ago\nData Entry Operator\nv-tech d...   Davanagere\n+9
# 8   Hot\n2 days ago\nData Entry Executive\nv-tech ...       Idukki\n+9
# 9   Hot\n2 days ago\nData Entry Executive\nv-tech ...    Bangalore\n+9
# 10
# 11
# 12  Hot\n2 days ago\nRecruiter Execuive\naasaanjob...      Mumbai City
# 13  4 days ago\nImmediate Openings For Testing\ndi...    Singapore\n+1
# 14  4 days ago\nWalk-in Interview for Tele Calling...        Bangalore
# 15
# 16
# 17
# 18  Hot\n0 days ago\nTrainee Product Specialist - ...  Other Karnataka
# 19  Hot\n0 days ago\nSr. Nodejs Developer\nmobile ...      Chennai\n+1
# 20  Hot\n0 days ago\nNodeJS Developer\ncollege dun...    Other Haryana
# 21
# ...

# %% [markdown]
# QUESTION 2

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_features__wJid6"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)

# %%
print(len(job_title),len(job_location))
# Out:
# 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location})
df
# Out:
#                    Title        Location
# 0             1 week ago   Bangalore\n+4
# 1    Premium\n1 week ago       Bangalore
# 2            1 month ago   Bangalore\n+1
# 3            3 weeks ago   Bangalore\n+1
# 4            3 weeks ago  Bangalore\n+14
# 5            3 weeks ago   Bangalore\n+1
# 6            1 month ago   Bangalore\n+7
# 7            1 month ago  Bangalore\n+14
# 8            1 month ago   Bangalore\n+2
# 9            1 month ago   Bangalore\n+4
# 10           1 month ago  Bangalore\n+13
# 11           1 month ago  Bangalore\n+14
# 12           1 month ago  Bangalore\n+13
# 13           1 month ago  Bangalore\n+13
# 14  Premium\n1 month ago   Bangalore\n+8
# 15           1 month ago       Bangalore
# 16   Premium\n5 days ago   Bangalore\n+1
# 17            5 days ago       Bangalore
# 18   Premium\n4 days ago       Bangalore
# 19            5 days ago       Bangalore

# %% [markdown]
# QUESTION 3

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard__jjUmu  white-box-border jobCard"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)

company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')   
for i in company_tags:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 19 20 20 20

# %% [markdown]
# QUESTION 4

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
Brand=[]
Price=[]
Product_description=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_25b18c"]')
for i in brand_tags:
    brand=i.text
    Brand.append(brand)
    
price_tags=driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price_tags:
    price=i.text
    Price.append(price)

product_description_tags=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
for i in product_description_tags:
    product_description=i.text
    Product_description.append(product_description)

# %% [markdown]
# QUESTION 5

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
Brand=[]
Price=[]
Product_description=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_25b18c"]')
for i in brand_tags:
    brand=i.text
    Brand.append(brand)
    
price_tags=driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price_tags:
    price=i.text
    Price.append(price)

product_description_tags=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
for i in product_description_tags:
    product_description=i.text
    Product_description.append(product_description)

# %% [markdown]
# QUESTION 6

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
Brand=[]
Price=[]
Product_description=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags:
    brand=i.text
    Brand.append(brand)
    
price_tags=driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price_tags:
    price=i.text
    Price.append(price)

product_description_tags=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
for i in product_description_tags:
    product_description=i.text
    Product_description.append(product_description)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
#       2 for i in brand_tags:
#       3     brand=i.text
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:771, in WebDriver.find_elements(self, by, value)
#     767     value = f'[name="{value}"]'
#     769 # Return empty list if driver returns null
#     770 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 771 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
# ...

# %% [markdown]
# QUESTION 7

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.amazon.in")

# %%
    Title=[]
    Ratings=[]
    Price=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in title_tags:
    title=i.text
    Title.append(title)
    
ratings_tags=driver.find_elements(By.XPATH,'//i[@class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"]')
for i in ratings_tags:
    ratings=i.text
    Ratings.append(ratings)

price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags:
   price=i.text
  Price.append(price)

# %% [markdown]
# QUESTION 8

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.azquotes.com/")

# %%
Author=[]
Quotes=[]
Types_of_quotes=[]

# %%
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags:
    author=i.text
    Author.append(author)
    
quotes_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quotes_tags:
    quotes=i.text
    Quotes.append(quotes)

types_of_quotes_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in types_of_quotes_tags:
   types_of_quotes=i.text
  Types_of_quotes.append(types_of_quotes)

# %% [markdown]
# QUESTION 9

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.jagranjosh.com/")
